# %%
import requests 
from bs4 import BeautifulSoup

# %%
url = "http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1"
r = requests.get(url)
c = r.content
soup = BeautifulSoup(c,"html.parser")
all = soup.find_all("div", {"class": "soldDetails"})

# %%
page_num = 40

# %%
list = []

base_url = url+"&index="
print(base_url)

for page in range(0,int(page_num)*25,25):
    print(base_url + str(page))
    r = requests.get(base_url + str(page))
    c = r.content
    soup = BeautifulSoup(c,"html.parser")
    all = soup.find_all("div", {"class": "soldDetails"})

    for item in all:
        d = {}


        #'address'
        try:
            d["Address"] = item.find("a", {"class":"soldAddress"}).text
        except:
            d["Address"] = None

        #'price'
        try:
            d["Price"] = item.find("td", {"class":"soldPrice"}).text[1:]
        except:
            d["Price"] = None

        #Building type
        try:
            d["Building Type"] = item.find("td", {"class":"soldType"}).text.split(",")[0]
        except:
            d["Building Type"] = None

        #Leasehold type
        try:
            d["Leasehold Type"] = item.find("td", {"class":"soldType"}).text.split(",")[1].strip()
        except:
            d["Leasehold Type"] = None

        #Number of Beds
        try:
            d["Bedrooms"] = item.find("td", {"class":"noBed"}).text.split(" ")[0]
        except:
            d["Bedrooms"]

        list.append(d)
# Out:
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=0
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=25
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=50
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=75
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=100
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=125
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=150
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=175
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=200
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=225
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=250
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=275
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=300
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=325
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=350
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=375
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=400
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=425
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=450
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=475
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=500
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=525
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=550
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=575
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=600
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=625
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=650
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=675
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=700
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=725
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=750
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=775
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=800
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=825
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=850
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=875
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=900
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=925
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=950
# http://www.rightmove.co.uk/house-prices/detail.html?country=england&locationIdentifier=REGION%5E1231&searchLocation=Southampton&radius=3.0&year=1&index=975

# %%
list
# Out:
# [{'Address': '6, Coulsdon Road, Hedge End, Southampton, Hampshire SO30 0JR',
#   'Bedrooms': '4',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '290,000'},
#  {'Address': "35, Harvest Road, Chandler's Ford, Eastleigh, Hampshire SO53 4HE",
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '426,500'},
#  {'Address': 'Flat 6, Latimer Gate, Bernard Street, Southampton SO14 3ER',
#   'Bedrooms': '3',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '240,500'},
#  {'Address': '86, Malmesbury Road, Shirley, Southampton SO15 5FQ',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '190,000'},
#  {'Address': '2, Fry Close, Hamble, Southampton, Hampshire SO31 4PF',
#   'Bedrooms': '4',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '350,000'},
#  {'Address': '68, Woodlands Road, Ashurst, Southampton, Hampshire SO40 7AF',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '360,000'},
#  {'Address': '64, Tides Way, Marchwood, Southampton, Hampshire SO40 4LB',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '240,000'},
#  {'Address': '6, Bramley Gardens, Horton Heath, Eastleigh, Hampshire SO50 7QB',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '400,000'},
#  {'Address': '28, Great Well Drive, Romsey, Hampshire SO51 7QP',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '257,500'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '170,000'},
#  {'Address': '89, Archery Grove, Woolston, Southampton SO19 9ET',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '256,000'},
#  {'Address': '34, Adams Road, Hythe, Southampton, Hampshire SO45 3JU',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '250,000'},
#  {'Address': '15, Langdown Lawn Close, Hythe, Southampton, Hampshire SO45 5GW',
#   'Bedrooms': '5',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '274,000'},
#  {'Address': '19, Foundry Lane, Southampton SO15 3FX',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Leasehold',
#   'Price': '205,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '95,000'},
#  {'Address': '101, Stanton Road, Southampton SO15 4HU',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '239,000'},
#  {'Address': '53, Pembrey Close, Southampton SO16 8HE',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '210,000'},
#  {'Address': '58, Brickfield Road, Southampton SO17 3AE',
#   'Bedrooms': '4',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '217,000'},
#  {'Address': "84, Pantheon Road, Chandler's Ford, Eastleigh, Hampshire SO53 2NS",
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '320,000'},
#  {'Address': "40, Pantheon Road, Chandler's Ford, Eastleigh, Hampshire SO53 2NS",
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '295,000'},
#  {'Address': '5, Collett Close, Hedge End, Southampton, Hampshire SO30 2RR',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '290,000'},
#  {'Address': '30, Crescent Road, North Baddesley, Southampton, Hampshire SO52 9HS',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '278,000'},
#  {'Address': "21, Queens Road, Chandler's Ford, Eastleigh, Hampshire SO53 5AH",
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '586,000'},
#  {'Address': "7, Tyrrel Road, Chandler's Ford, Eastleigh, Hampshire SO53 1GG",
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '620,000'},
#  {'Address': '176, Winchester Road, Southampton SO16 6UG',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '222,000'},
#  {'Address': '22, Mossleigh Avenue, Rownhams, Southampton, Hampshire SO16 8FU',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '395,000'},
#  {'Address': '7, Westover Road, Southampton SO16 9BJ',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '250,000'},
#  {'Address': '71, Bassett Green Close, Southampton SO16 3QX',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '410,000'},
#  {'Address': '11, Old Bridge House Road, Bursledon, Southampton, Hampshire SO31 8AJ',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '225,000'},
#  {'Address': '23, Barton Drive, Hedge End, Southampton, Hampshire SO30 2FD',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '280,000'},
#  {'Address': 'Flat 10, Osborne House, Grosvenor Square, Southampton SO15 2DA',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '233,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '110,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '88,000'},
#  {'Address': '1, Edwina Close, Southampton SO19 7BJ',
#   'Bedrooms': '4',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '280,000'},
#  {'Address': '47, Hunters Crescent, Romsey, Hampshire SO51 7UG',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '344,000'},
#  {'Address': '4, Southampton Road, Romsey, Hampshire SO51 8AF',
#   'Bedrooms': '5',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '622,500'},
#  {'Address': '20a, Simmons Close, Hedge End, Southampton, Hampshire SO30 4NT',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '140,000'},
#  {'Address': '6, Chamberlayne Road, Netley Abbey, Southampton, Hampshire SO31 5DA',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Leasehold',
#   'Price': '258,000'},
#  {'Address': 'Flat 30, Tremona Court, Tremona Road, Shirley, Southampton SO16 6TH',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '84,000'},
#  {'Address': '4, Paxton Close, Hedge End, Southampton, Hampshire SO30 0PB',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '250,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '159,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '325,000'},
#  {'Address': '4, Centaury Gardens, Horton Heath, Eastleigh, Hampshire SO50 7NY',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '266,000'},
#  {'Address': '22, Cumberland Way, Dibden, Southampton, Hampshire SO45 5TW',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '130,000'},
#  {'Address': '179a, Warsash Road, Warsash, Southampton, Hampshire SO31 9JE',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '270,000'},
#  {'Address': '51, Merryfield, Fareham, Hampshire PO14 4SF',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '350,000'},
#  {'Address': '230, Market Street, Eastleigh, Hampshire SO50 5QB',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Leasehold',
#   'Price': '215,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '205,000'},
#  {'Address': '5, Burley Close, Totton, Southampton, Hampshire SO40 8GA',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '375,000'},
#  {'Address': '165, High Street, Eastleigh, Hampshire SO50 5LX',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '230,000'},
#  {'Address': '21, Dartington Road, Bishopstoke, Eastleigh, Hampshire SO50 6NQ',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '383,250'},
#  {'Address': 'Flat 20, Nightingale Walk, Royal Victoria Country Park, Netley Abbey, Southampton, Hampshire SO31 5GA',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '257,000'},
#  {'Address': '45, Coxford Close, Southampton SO16 6DD',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '202,500'},
#  {'Address': '1, Plover Close, Southampton SO16 8EU',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '282,500'},
#  {'Address': '38, Milton Road, Southampton SO15 2HR',
#   'Bedrooms': '6',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '285,000'},
#  {'Address': '7, Tintagel Close, Southampton SO16 8HX',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '208,836'},
#  {'Address': 'Flat 18, Queens Court, Hill Lane, Southampton SO15 5RR',
#   'Bedrooms': '0',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '90,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '101,000'},
#  {'Address': '27, Barry Road, Southampton SO19 5LQ',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '215,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '94,000'},
#  {'Address': '4, Kennet Close, West End, Southampton, Hampshire SO18 3JY',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '211,000'},
#  {'Address': '48, Taunton Drive, Southampton SO18 5BU',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '328,000'},
#  {'Address': '4, Malvern Drive, Dibden Purlieu, Southampton, Hampshire SO45 5QY',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '442,500'},
#  {'Address': "21, Maytree Road, Chandler's Ford, Eastleigh, Hampshire SO53 5RT",
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '349,950'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '249,950'},
#  {'Address': '16, Tinning Way, Eastleigh, Hampshire SO50 9QE',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '317,500'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '199,995'},
#  {'Address': '34a, Windrush Road, Southampton SO16 9DD',
#   'Bedrooms': '0',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '74,500'},
#  {'Address': '11, Freshfield Road, Southampton SO15 8QW',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '174,500'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '150,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '187,500'},
#  {'Address': "116, Pine Road, Chandler's Ford, Eastleigh, Hampshire SO53 1JT",
#   'Bedrooms': '5',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '595,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '253,000'},
#  {'Address': 'Apartment, 28, Barfoot Road, Hedge End, Southampton, Hampshire SO30 2LL',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '193,000'},
#  {'Address': '18, Foord Road, Hedge End, Southampton, Hampshire SO30 0DD',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '452,500'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '120,000'},
#  {'Address': '13, Symes Road, Romsey, Hampshire SO51 5BD',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '158,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '528,000'},
#  {'Address': '53, Flint Close, Southampton SO19 6RQ',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '186,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '185,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '123,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '610,000'},
#  {'Address': '6, Ashfield View, North Baddesley, Southampton, Hampshire SO52 9AH',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '255,000'},
#  {'Address': '19, Old Common Gardens, Locks Heath, Southampton, Hampshire SO31 6AX',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '210,000'},
#  {'Address': '58, Hoddinott Road, Eastleigh, Hampshire SO50 5SN',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '168,000'},
#  {'Address': '12, Chadwick Road, Eastleigh, Hampshire SO50 9GE',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '280,000'},
#  {'Address': '6, Forest View, Southampton SO14 2BZ',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '350,000'},
#  {'Address': '11, Albany Road, Southampton SO15 3EF',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '232,000'},
#  {'Address': '1, Canton Street, Southampton SO15 2DJ',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '275,000'},
#  {'Address': '54, Forest Hills Drive, Townhill Park, Southampton SO18 2FW',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '250,000'},
#  {'Address': '23, Spencer Road, Southampton SO19 6QU',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '220,000'},
#  {'Address': '20, Radcliffe Road, Northam, Southampton SO14 0PG',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '195,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '350,000'},
#  {'Address': '54, Newton Lane, Romsey, Hampshire SO51 8GX',
#   'Bedrooms': '4',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '680,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '567,500'},
#  {'Address': '3, Oakfields, Eastleigh, Hampshire SO50 4RP',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '529,000'},
#  {'Address': 'Willows End, Walpole Lane, Swanwick, Southampton, Hampshire SO31 7AX',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '690,000'},
#  {'Address': '34, Addison Road, Sarisbury Green, Southampton, Hampshire SO31 7ER',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '227,000'},
#  {'Address': '33, Borden Way, North Baddesley, Southampton, Hampshire SO52 9PD',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '183,500'},
#  {'Address': '22, Cambria Drive, Dibden, Southampton, Hampshire SO45 5UW',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '218,000'},
#  {'Address': '48, Elkins Square, Bishopstoke, Eastleigh, Hampshire SO50 8HF',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '195,000'},
#  {'Address': '35, Eyeworth Walk, Dibden, Southampton, Hampshire SO45 5WF',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '206,000'},
#  {'Address': '26, Saffron Way, Whiteley, Fareham, Hampshire PO15 7LQ',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '225,000'},
#  {'Address': '82, Barnes Lane, Sarisbury Green, Southampton, Hampshire SO31 7BT',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '345,000'},
#  {'Address': '7, The Bramblings, Totton, Southampton, Hampshire SO40 8UP',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '152,000'},
#  {'Address': '44, Ethelred Gardens, Totton, Southampton, Hampshire SO40 8UA',
#   'Bedrooms': '1',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '162,250'},
#  {'Address': '12, Barrington Close, Eastleigh, Hampshire SO50 4SH',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '227,000'},
#  {'Address': '57, Doncaster Road, Eastleigh, Hampshire SO50 5QP',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Leasehold',
#   'Price': '250,000'},
#  {'Address': '13, Kings Copse Road, Hedge End, Southampton, Hampshire SO30 0PQ',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '228,950'},
#  {'Address': '24, Spicers Way, Totton, Southampton, Hampshire SO40 9AW',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '285,000'},
#  {'Address': '23, Oaktree Way, Eastleigh, Hampshire SO50 4JN',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '274,500'},
#  {'Address': '24, Benbow Gardens, Calmore, Southampton, Hampshire SO40 2SX',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '211,000'},
#  {'Address': '53, Rufus Gardens, Totton, Southampton, Hampshire SO40 8TA',
#   'Bedrooms': '1',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '179,950'},
#  {'Address': '12, Seaford Close, Bursledon, Southampton, Hampshire SO31 8GL',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '215,000'},
#  {'Address': '8, Belmont Close, Dibden Purlieu, Southampton, Hampshire SO45 4NL',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '285,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '120,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '102,500'},
#  {'Address': '9, Brean Close, Southampton SO16 9NQ',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '200,000'},
#  {'Address': '33, Mayfair Gardens, Southampton SO15 2TW',
#   'Bedrooms': '4',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '450,000'},
#  {'Address': 'Flat 15, Alexander Court, Park Road, Freemantle, Southampton SO15 3AE',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '110,000'},
#  {'Address': '47, Mayfair Gardens, Southampton SO15 2TW',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '290,000'},
#  {'Address': '16, Colebrook Avenue, Southampton SO15 5NR',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '342,500'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '126,500'},
#  {'Address': '31, Hurricane Drive, Rownhams, Southampton, Hampshire SO16 8LH',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '420,000'},
#  {'Address': '43, Liverpool Street, Southampton SO14 6FZ',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '205,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '211,500'},
#  {'Address': '70, Middle Street, Southampton SO14 6HW',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '200,000'},
#  {'Address': '12, Drove Road, Southampton SO19 8GJ',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '210,000'},
#  {'Address': '92, Copperfield Road, Southampton SO16 3NY',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '205,000'},
#  {'Address': '182, Manor Road North, Southampton SO19 2EB',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '215,000'},
#  {'Address': "30, Tees Close, Chandler's Ford, Eastleigh, Hampshire SO53 4RU",
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '335,000'},
#  {'Address': '17, Yarrow Way, Locks Heath, Southampton, Hampshire SO31 6TH',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '214,000'},
#  {'Address': '23, Little Park Close, Hedge End, Southampton, Hampshire SO30 4AD',
#   'Bedrooms': '4',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '280,000'},
#  {'Address': "9, Lincoln Place, Chandler's Ford, Eastleigh, Hampshire SO53 3LP",
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '440,000'},
#  {'Address': '33, Royston Avenue, Boyatt Wood, Eastleigh, Hampshire SO50 4NH',
#   'Bedrooms': '4',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '305,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '110,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '248,000'},
#  {'Address': '3, Roman Way, Dibden Purlieu, Southampton, Hampshire SO45 4RP',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '387,500'},
#  {'Address': '54, Yarrow Way, Locks Heath, Southampton, Hampshire SO31 6XD',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '232,000'},
#  {'Address': 'Flat 10, Silverweed Court, Upper Brook Drive, Locks Heath, Southampton, Hampshire SO31 6ZU',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '155,000'},
#  {'Address': '4, Oatfield Gardens, Calmore, Southampton, Hampshire SO40 2UL',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '235,000'},
#  {'Address': '189, High Street, Eastleigh, Hampshire SO50 5LX',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Leasehold',
#   'Price': '229,000'},
#  {'Address': '4, Furzedale Gardens, Hythe, Southampton, Hampshire SO45 3HR',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '245,000'},
#  {'Address': '76, Captains Place, Southampton SO14 3TF',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '246,000'},
#  {'Address': '82, Romsey Road, Southampton SO16 4DE',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '180,000'},
#  {'Address': '3, Cranbury Place, Southampton SO14 0LG',
#   'Bedrooms': '4',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Leasehold',
#   'Price': '347,000'},
#  {'Address': '13, Rampart Road, Southampton SO18 1AT',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '290,000'},
#  {'Address': '73, Ivy Road, St Denys, Southampton SO17 2JB',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '260,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '150,000'},
#  {'Address': '53, The Hundred, Romsey, Hampshire SO51 8GE',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '340,000'},
#  {'Address': '49, Penshurst Way, Eastleigh, Hampshire SO50 4RH',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '145,000'},
#  {'Address': '43, Pennington Close, Colden Common, Winchester, Hampshire SO21 1UR',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '367,000'},
#  {'Address': "7, Burley Down, Chandler's Ford, Eastleigh, Hampshire SO53 4NR",
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '455,000'},
#  {'Address': 'Flat A, 5, Hamilton Road, Eastleigh, Hampshire SO50 6AU',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '145,000'},
#  {'Address': '19, Filton Close, Calmore, Southampton, Hampshire SO40 2UW',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '207,500'},
#  {'Address': '21, Portal Road, Bishopstoke, Eastleigh, Hampshire SO50 6AX',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '256,000'},
#  {'Address': '10, Causton Gardens, Eastleigh, Hampshire SO50 9PJ',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '330,000'},
#  {'Address': '41, Downscroft Gardens, Hedge End, Southampton, Hampshire SO30 4RS',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '200,000'},
#  {'Address': '27, Meadowmead Avenue, Southampton SO15 4LW',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '286,500'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '163,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '73,000'},
#  {'Address': '33, Beechdale Close, Calmore, Southampton, Hampshire SO40 2QH',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '179,000'},
#  {'Address': '11, Six Oaks Road, North Baddesley, Southampton, Hampshire SO52 9JB',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '360,000'},
#  {'Address': '6, Tavistock Close, Romsey, Hampshire SO51 7TQ',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '267,000'},
#  {'Address': '11, Wessex Gardens, Romsey, Hampshire SO51 5RD',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '244,000'},
#  {'Address': '8, Stanley Road, Totton, Southampton, Hampshire SO40 3PR',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '260,000'},
#  {'Address': '207, Chamberlayne Road, Eastleigh, Hampshire SO50 5HZ',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '240,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '303,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '395,000'},
#  {'Address': 'Flat 32, Hatherley Mansions, Shirley Road, Southampton SO15 3HZ',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '109,000'},
#  {'Address': '2, Edwin Jones Green, Southampton SO15 2RY',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '195,000'},
#  {'Address': '57, Gainsford Road, Southampton SO19 7AW',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '267,500'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '109,000'},
#  {'Address': '22, Argosy Crescent, Eastleigh, Hampshire SO50 5RW',
#   'Bedrooms': '4',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '300,000'},
#  {'Address': '15, Rampart Road, Southampton SO18 1AT',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '245,000'},
#  {'Address': '8, Romford Road, Warsash, Southampton, Hampshire SO31 9GZ',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '265,000'},
#  {'Address': '33, Rownhams Lane, North Baddesley, Southampton, Hampshire SO52 9HR',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '355,000'},
#  {'Address': '2, Ripplewood, Marchwood, Southampton, Hampshire SO40 4SH',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '335,000'},
#  {'Address': '9, Laurence Mews, Romsey, Hampshire SO51 7SB',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '320,000'},
#  {'Address': 'Flat 3, Osborne Mews, Allbrook Hill, Eastleigh, Hampshire SO50 4JQ',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '176,000'},
#  {'Address': '26, Nash Road, Dibden Purlieu, Southampton, Hampshire SO45 4RS',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '301,000'},
#  {'Address': '95, Itchen Avenue, Bishopstoke, Eastleigh, Hampshire SO50 8NL',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '277,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '235,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '235,000'},
#  {'Address': "Flat 8, Charlotte Court, Merdon Avenue, Chandler's Ford, Eastleigh, Hampshire SO53 1TZ",
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '140,000'},
#  {'Address': "74, Lakewood Road, Chandler's Ford, Eastleigh, Hampshire SO53 5AA",
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '980,000'},
#  {'Address': "19, Beechwood Crescent, Chandler's Ford, Eastleigh, Hampshire SO53 5PE",
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '730,000'},
#  {'Address': "93, Hocombe Road, Chandler's Ford, Eastleigh, Hampshire SO53 5QB",
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '976,600'},
#  {'Address': '24, Barnbrook Road, Sarisbury Green, Southampton, Hampshire SO31 7BP',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '275,000'},
#  {'Address': '7, Barnes Close, Sarisbury Green, Southampton, Hampshire SO31 7BU',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '212,500'},
#  {'Address': '57, Trimaran Road, Warsash, Southampton, Hampshire SO31 9BF',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '405,000'},
#  {'Address': '11, Fontwell Close, Calmore, Southampton, Hampshire SO40 2TN',
#   'Bedrooms': '5',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '284,950'},
#  {'Address': '7, Silvers Wood, Calmore, Southampton, Hampshire SO40 2SZ',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '245,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '176,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '425,000'},
#  {'Address': 'Flat 16, Hambleside Court, Hamble Lane, Hamble, Southampton, Hampshire SO31 4QE',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '120,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '155,000'},
#  {'Address': '49a, Hollybank Crescent, Hythe, Southampton, Hampshire SO45 5FZ',
#   'Bedrooms': '3',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '118,000'},
#  {'Address': '31, South East Crescent, Sholing, Southampton SO19 8PR',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Leasehold',
#   'Price': '220,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '265,000'},
#  {'Address': '8, Landseer Road, Southampton SO19 1EE',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '158,000'},
#  {'Address': '22, Bramshott Road, Southampton SO19 9ND',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '150,000'},
#  {'Address': '14, Saxholm Dale, Southampton SO16 7HA',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '387,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '174,000'},
#  {'Address': '65, Studland Road, Southampton SO16 9BG',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '166,500'},
#  {'Address': '75, Waterloo Road, Southampton SO15 3BR',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '305,000'},
#  {'Address': '26, Northolt Gardens, Southampton SO16 8HA',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '208,000'},
#  {'Address': '23, Colby Street, Southampton SO16 9RT',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '174,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '241,000'},
#  {'Address': '10, Falkland Road, Southampton SO15 4GZ',
#   'Bedrooms': '0',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '260,000'},
#  {'Address': '30, Copperfield Road, Southampton SO16 3NX',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '249,000'},
#  {'Address': '63, Castle Road, Bitterne Park, Southampton SO18 1QP',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '317,500'},
#  {'Address': '9, Hayle Road, West End, Southampton, Hampshire SO18 3QE',
#   'Bedrooms': '0',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '250,000'},
#  {'Address': '491, Hinkler Road, Thornhill, Southampton SO19 6DL',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '188,000'},
#  {'Address': '192, Honeysuckle Road, Southampton SO16 3BU',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '191,000'},
#  {'Address': '147, Bridge Road, Sarisbury Green, Southampton, Hampshire SO31 7EN',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '360,000'},
#  {'Address': "5, Colton Copse, Chandler's Ford, Eastleigh, Hampshire SO53 4HQ",
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '300,500'},
#  {'Address': '78, Coates Road, Sholing, Southampton SO19 0HJ',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '280,000'},
#  {'Address': '5, Ingle Glen, Dibden Purlieu, Southampton, Hampshire SO45 4ND',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '219,000'},
#  {'Address': '114, Church Road, Woolston, Southampton SO19 9FX',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '267,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '300,000'},
#  {'Address': '30, Lower Brownhill Road, Southampton SO16 9QJ',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '185,000'},
#  {'Address': '37, Oakwood Drive, Lordswood, Southampton SO16 8EJ',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '225,000'},
#  {'Address': '9, Flamborough Close, Millbrook, Southampton SO16 9QP',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '178,000'},
#  {'Address': '187, Upper Deacon Road, Southampton SO19 5LE',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Leasehold',
#   'Price': '333,000'},
#  {'Address': '8, Noble Road, Hedge End, Southampton, Hampshire SO30 0PH',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '220,000'},
#  {'Address': '17, Hepworth Close, Southampton SO19 0SX',
#   'Bedrooms': '1',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '157,500'},
#  {'Address': '22, Scott Paine Drive, Hythe, Southampton, Hampshire SO45 6JB',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '212,500'},
#  {'Address': 'Flat 12, Lawrence Court, Lawrence Grove, Southampton SO19 9QD',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '124,000'},
#  {'Address': 'Flat 34, Oceana Boulevard, Briton Street, Southampton SO14 3HU',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '184,000'},
#  {'Address': '95, Rosebery Avenue, Hythe, Southampton, Hampshire SO45 3GY',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '250,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold\xa0(New Build)',
#   'Price': '499,950'},
#  {'Address': '310, Wimpson Lane, Southampton SO16 4PX',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '122,500'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '56,000'},
#  {'Address': '1c, Alexandra Road, Southampton SO15 5DH',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '250,000'},
#  {'Address': '16, Merridale Road, Southampton SO19 7AD',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '310,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '150,000'},
#  {'Address': '32, Methuen Street, Southampton SO14 6FR',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '280,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '297,000'},
#  {'Address': '39, Kingsfield Gardens, Bursledon, Southampton, Hampshire SO31 8AY',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '292,000'},
#  {'Address': 'Hacketts, High Street, Bursledon, Southampton, Hampshire SO31 8DL',
#   'Bedrooms': '1',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '1,600,000'},
#  {'Address': '11, Vaughan Road, Dibden, Southampton, Hampshire SO45 5UL',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '199,950'},
#  {'Address': '30, Lovage Road, Whiteley, Fareham, Hampshire PO15 7LD',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '294,000'},
#  {'Address': 'The Bungalow, Viney Avenue, Romsey, Hampshire SO51 7NR',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '300,000'},
#  {'Address': "7, Common Close, Chandler's Ford, Eastleigh, Hampshire SO53 1HF",
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '360,000'},
#  {'Address': '18, Vine Close, Sarisbury Green, Southampton, Hampshire SO31 7DB',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '320,000'},
#  {'Address': '20, Denbigh Close, Boyatt Wood, Eastleigh, Hampshire SO50 4QN',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '325,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '294,750'},
#  {'Address': '20, Portelet Place, Hedge End, Southampton, Hampshire SO30 0LZ',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '465,000'},
#  {'Address': '10, Portal Road, Totton, Southampton, Hampshire SO40 3GB',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '225,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '385,000'},
#  {'Address': '14, Haileybury Gardens, Hedge End, Southampton, Hampshire SO30 2AP',
#   'Bedrooms': '1',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '158,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Leasehold',
#   'Price': '185,000'},
#  {'Address': '34, Harewood Close, Boyatt Wood, Eastleigh, Hampshire SO50 4NZ',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '225,000'},
#  {'Address': '124, Missenden Acres, Hedge End, Southampton, Hampshire SO30 2AQ',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '405,000'},
#  {'Address': '5, Jasmine Road, Hedge End, Southampton, Hampshire SO30 4SX',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '300,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '242,000'},
#  {'Address': '15a, Tranby Road, Southampton SO19 7GY',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '135,000'},
#  {'Address': '6, West Road, Woolston, Southampton SO19 9AJ',
#   'Bedrooms': '4',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Leasehold',
#   'Price': '325,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '195,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '210,000'},
#  {'Address': '35, Cardinal Place, Maybush, Southampton SO16 4HR',
#   'Bedrooms': '4',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '289,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '145,000'},
#  {'Address': '17, Charlton Road, Shirley, Southampton SO15 5FL',
#   'Bedrooms': '4',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '300,000'},
#  {'Address': '33a, Paynes Road, Freemantle, Southampton SO15 3BX',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '123,000'},
#  {'Address': '16, Alder Road, Southampton SO16 5EP',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '210,000'},
#  {'Address': '34, Cowdray Close, Lordswood, Southampton SO16 8EB',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '217,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '151,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '180,000'},
#  {'Address': '31, Somerton Avenue, Harefield, Southampton SO18 5BZ',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '233,000'},
#  {'Address': '2, Chessel Crescent, Southampton SO19 4BS',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '395,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '179,950'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '179,000'},
#  {'Address': '81, Cornwall Road, Southampton SO18 2AW',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '200,000'},
#  {'Address': '232, Northam Road, Southampton SO14 0QE',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '178,000'},
#  {'Address': '4, Atlantic Park View, West End, Southampton, Hampshire SO18 3RQ',
#   'Bedrooms': '1',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '152,500'},
#  {'Address': 'Flat 7, Deepdene, Midanbury Lane, Bitterne Park, Southampton SO18 4TQ',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '128,000'},
#  {'Address': '10, Vokes Close, Southampton SO19 8BN',
#   'Bedrooms': '4',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '310,000'},
#  {'Address': '232, Northam Road, Southampton SO14 0QE',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '178,000'},
#  {'Address': 'Melcombe, Lime Kiln Lane, Holbury, Southampton, Hampshire SO45 2HH',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '330,000'},
#  {'Address': '15, Cornflower Close, Locks Heath, Southampton, Hampshire SO31 6SP',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '268,000'},
#  {'Address': '11, Kelvin Road, Eastleigh, Hampshire SO50 9GB',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '265,000'},
#  {'Address': '4, School Road, Hythe, Southampton, Hampshire SO45 6BL',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '286,000'},
#  {'Address': 'Flat 12, Withewood Mansions, Shirley Road, Southampton SO15 3JA',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '112,000'},
#  {'Address': '26, Testwood Road, Freemantle, Southampton SO15 8RL',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '216,150'},
#  {'Address': '40, Green Park Road, Southampton SO16 9AB',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '133,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '180,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '90,000'},
#  {'Address': '31, Southern Road, West End, Southampton, Hampshire SO30 3ES',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '410,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '135,000'},
#  {'Address': '47, Rownhams Lane, North Baddesley, Southampton, Hampshire SO52 9HR',
#   'Bedrooms': '2',
# ...
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '167,500'},
#  {'Address': '34, Havendale, Hedge End, Southampton, Hampshire SO30 0FD',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '210,000'},
#  {'Address': 'Flat 24, Sarisbury Gate, Dove Gardens, Park Gate, Southampton, Hampshire SO31 7FP',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '105,000'},
#  {'Address': '84, Whites Way, Hedge End, Southampton, Hampshire SO30 2JY',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '302,000'},
#  {'Address': '47, Fawn Crescent, Hedge End, Southampton, Hampshire SO30 2QD',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '167,000'},
#  {'Address': '19, Rosebery Crescent, Eastleigh, Hampshire SO50 4HX',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '237,350'},
#  {'Address': '2, Pound Road, Bursledon, Southampton, Hampshire SO31 8FE',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Leasehold',
#   'Price': '248,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '200,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '189,995'},
#  {'Address': '4, Cirrus Gardens, Hamble, Southampton, Hampshire SO31 4RH',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '497,500'},
#  {'Address': '114, Knighton Road, Southampton SO19 2FN',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '180,900'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '62,500'},
#  {'Address': '51, Clifton Road, Southampton SO15 4GY',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '245,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '165,945'},
#  {'Address': '118, Bellemoor Road, Southampton SO15 7QY',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '360,000'},
#  {'Address': '10, Kingsley Road, Southampton SO15 8QQ',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '212,500'},
#  {'Address': '41, Cardinal Place, Maybush, Southampton SO16 4HR',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '270,000'},
#  {'Address': 'Flat 43, Brook Court, Brook Valley, Maybush, Southampton SO16 6SR',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '138,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '220,000'},
#  {'Address': '33, The Avenue, Southampton SO17 1XN',
#   'Bedrooms': '1',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Leasehold',
#   'Price': '121,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '220,000'},
#  {'Address': '33, The Avenue, Southampton SO17 1XN',
#   'Bedrooms': '1',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Leasehold',
#   'Price': '121,000'},
#  {'Address': '16, Chafen Road, Southampton SO18 1BB',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '300,000'},
#  {'Address': '356, Priory Road, St Denys, Southampton SO17 2LQ',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '190,000'},
#  {'Address': '5, Maldon Road, Southampton SO19 7AF',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '225,000'},
#  {'Address': '7, September Close, West End, Southampton, Hampshire SO30 3BE',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '220,000'},
#  {'Address': '41, Maldon Road, Southampton SO19 7AF',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '240,000'},
#  {'Address': '57, Mordaunt Road, Southampton SO14 6GP',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '273,000'},
#  {'Address': '11, St Helena Gardens, Southampton SO18 2DT',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '256,000'},
#  {'Address': 'Flat 43, Homepoint House, Mersham Gardens, Bitterne, Southampton SO18 6TX',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '84,500'},
#  {'Address': 'Flat 5, Brampton Manor, Beechmount Road, Southampton SO16 3JE',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '169,000'},
#  {'Address': '10, Walnut Avenue, Swaythling, Southampton SO18 2HS',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '193,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '144,000'},
#  {'Address': '15, Manor Road, Holbury, Southampton, Hampshire SO45 2NQ',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '180,000'},
#  {'Address': '8, Shapton Close, Holbury, Southampton, Hampshire SO45 2QJ',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '285,000'},
#  {'Address': '31, Studley Avenue, Holbury, Southampton, Hampshire SO45 2PP',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '205,000'},
#  {'Address': '37, Wellington Close, Dibden Purlieu, Southampton, Hampshire SO45 4RL',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '440,000'},
#  {'Address': '7, Roberts Road, Hythe, Southampton, Hampshire SO45 5DH',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '297,500'},
#  {'Address': '32, Withy Close, Romsey, Hampshire SO51 7SA',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '475,000'},
#  {'Address': '9, Meon Road, Romsey, Hampshire SO51 5PU',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '297,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold\xa0(New Build)',
#   'Price': '345,000'},
#  {'Address': '44, Warsash Road, Warsash, Southampton, Hampshire SO31 9HX',
#   'Bedrooms': '4',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '350,000'},
#  {'Address': "6, Welles Road, Chandler's Ford, Eastleigh, Hampshire SO53 2GQ",
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '395,000'},
#  {'Address': '16, Ashwood Gardens, Totton, Southampton, Hampshire SO40 8SZ',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '375,000'},
#  {'Address': '1, St Simon Close, Locks Heath, Southampton, Hampshire SO31 6DH',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '347,000'},
#  {'Address': '1, St Simon Close, Locks Heath, Southampton, Hampshire SO31 6DH',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '347,000'},
#  {'Address': "1, Welles Road, Chandler's Ford, Eastleigh, Hampshire SO53 2GQ",
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '305,000'},
#  {'Address': '19, Shetland Close, Totton, Southampton, Hampshire SO40 8HY',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '291,000'},
#  {'Address': '11, Lapwing Drive, Totton, Southampton, Hampshire SO40 8UH',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '280,000'},
#  {'Address': '13, Norton Close, Southampton SO19 2EY',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '206,500'},
#  {'Address': '39, Lodge Drive, Dibden Purlieu, Southampton, Hampshire SO45 4LX',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '250,000'},
#  {'Address': 'Fishponds, Fountains Park, Netley Abbey, Southampton, Hampshire SO31 5HB',
#   'Bedrooms': '5',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '880,000'},
#  {'Address': '4, Quintilis Mews, Lordswood, Southampton SO16 5LN',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '275,000'},
#  {'Address': '23, Lime Avenue, Southampton SO19 8NY',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Leasehold',
#   'Price': '218,500'},
#  {'Address': '66, Bluebell Road, Southampton SO16 3LQ',
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '210,000'},
#  {'Address': '7, Adelaide Road, Southampton SO17 2HU',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '205,000'},
#  {'Address': '6, Cumberland Way, Dibden, Southampton, Hampshire SO45 5TW',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '210,000'},
#  {'Address': '2, The Brackens, Dibden Purlieu, Southampton, Hampshire SO45 5RY',
#   'Bedrooms': '1',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '164,000'},
#  {'Address': '91, Dumas Drive, Whiteley, Fareham, Hampshire PO15 7FS',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '390,000'},
#  {'Address': "39, Wood End Way, Chandler's Ford, Eastleigh, Hampshire SO53 4LN",
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '370,000'},
#  {'Address': "7, The Tanyards, Chandler's Ford, Eastleigh, Hampshire SO53 1TJ",
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '585,000'},
#  {'Address': "6, Partry Close, Chandler's Ford, Eastleigh, Hampshire SO53 4SS",
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '470,000'},
#  {'Address': '10, Pembroke Close, Eastleigh, Hampshire SO50 4QY',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '285,000'},
#  {'Address': "5, Cox Row, Chandler's Ford, Eastleigh, Hampshire SO53 3EY",
#   'Bedrooms': '3',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '287,500'},
#  {'Address': "7, Cambridge Green, Chandler's Ford, Eastleigh, Hampshire SO53 3EQ",
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '215,000'},
#  {'Address': '4, Killarney Close, Southampton SO19 0PW',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '159,995'},
#  {'Address': '39, Belvedere Road, Dibden Purlieu, Southampton, Hampshire SO45 4NP',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '327,500'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '270,000'},
#  {'Address': 'Flat 12a, Nightingale Walk, Royal Victoria Country Park, Netley Abbey, Southampton, Hampshire SO31 5GA',
#   'Bedrooms': '1',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '129,950'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '200,000'},
#  {'Address': '119, Firgrove Road, Southampton SO15 3ET',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '150,000'},
#  {'Address': '36, Blakeney Road, Southampton SO16 9PE',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '169,500'},
#  {'Address': '97, Paynes Road, Freemantle, Southampton SO15 3BX',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '205,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '159,950'},
#  {'Address': '50, Torridge Gardens, West End, Southampton, Hampshire SO18 3NF',
#   'Bedrooms': '2',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '207,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '180,000'},
#  {'Address': '31, Onibury Road, Midanbury, Southampton SO18 2DB',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '200,000'},
#  {'Address': '103, St Blaize Road, Romsey, Hampshire SO51 7JY',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '235,000'},
#  {'Address': '2, Coriander Drive, Totton, Southampton, Hampshire SO40 8FS',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '223,000'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '142,500'},
#  {'Address': '2, Harewood Close, Boyatt Wood, Eastleigh, Hampshire SO50 4NZ',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '199,000'},
#  {'Address': '41, Fallow Crescent, Hedge End, Southampton, Hampshire SO30 2QQ',
#   'Bedrooms': '3',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '284,950'},
#  {'Address': '4, George Wright Close, Eastleigh, Hampshire SO50 5SJ',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '236,000'},
#  {'Address': '27, Lingwood Close, Bassett, Southampton SO16 7GB',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '460,000'},
#  {'Address': '3, Kirk Gardens, Totton, Southampton, Hampshire SO40 9UZ',
#   'Bedrooms': '2',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '325,000'},
#  {'Address': '5, Burton Road, Southampton SO15 2HZ',
#   'Bedrooms': '4',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '219,500'},
#  {'Address': '21, Castle Street, Southampton SO14 6GZ',
#   'Bedrooms': '4',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '210,000'},
#  {'Address': '8, Court Close, Calmore, Southampton, Hampshire SO40 2QW',
#   'Bedrooms': '2',
#   'Building Type': 'Flat',
#   'Leasehold Type': 'Leasehold',
#   'Price': '175,000'},
#  {'Address': '37, Sycamore Close, Romsey, Hampshire SO51 5SB',
#   'Bedrooms': '4',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '412,500'},
#  {'Address': None,
#   'Bedrooms': '',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '430,000'},
#  {'Address': '76, Pitmore Road, Allbrook, Eastleigh, Hampshire SO50 4LW',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '375,000'},
#  {'Address': '34, Devonshire Gardens, Bursledon, Southampton, Hampshire SO31 8HE',
#   'Bedrooms': '3',
#   'Building Type': 'Terraced',
#   'Leasehold Type': 'Freehold',
#   'Price': '244,000'},
#  {'Address': '12, Tadburn Road, Romsey, Hampshire SO51 5AU',
#   'Bedrooms': '2',
#   'Building Type': 'Semi-Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '335,000'},
#  {'Address': 'Treetops, Crampmoor Lane, Crampmoor, Romsey, Hampshire SO51 9AJ',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '735,000'},
#  {'Address': '49, Summerfields, Locks Heath, Southampton, Hampshire SO31 6NN',
#   'Bedrooms': '4',
#   'Building Type': 'Detached',
#   'Leasehold Type': 'Freehold',
#   'Price': '380,000'}]

# %%
import pandas as pd

# %%
#function to remove commas
def no_commas(x):
    y = int(x.replace(',', ''))
    return y

# %%
df = pd.DataFrame(list)
df = df.dropna(subset=["Address"])
df['Price'] = df['Price'].apply(no_commas)
df
# Out:
#                                                Address Bedrooms  \
# 0    6, Coulsdon Road, Hedge End, Southampton, Hamp...        4
# 1    35, Harvest Road, Chandler's Ford, Eastleigh, ...        4
# 2    Flat 6, Latimer Gate, Bernard Street, Southamp...        3
# 3    86, Malmesbury Road, Shirley, Southampton SO15...        3
# 4    2, Fry Close, Hamble, Southampton, Hampshire S...        4
# 5    68, Woodlands Road, Ashurst, Southampton, Hamp...        2
# 6    64, Tides Way, Marchwood, Southampton, Hampshi...        3
# 7    6, Bramley Gardens, Horton Heath, Eastleigh, H...        4
# 8     28, Great Well Drive, Romsey, Hampshire SO51 7QP        2
# 10   89, Archery Grove, Woolston, Southampton SO19 9ET        3
# 11   34, Adams Road, Hythe, Southampton, Hampshire ...        3
# 12   15, Langdown Lawn Close, Hythe, Southampton, H...        5
# 13              19, Foundry Lane, Southampton SO15 3FX        2
# 15             101, Stanton Road, Southampton SO15 4HU        3
# 16             53, Pembrey Close, Southampton SO16 8HE        3
# 17           58, Brickfield Road, Southampton SO17 3AE        4
# 18   84, Pantheon Road, Chandler's Ford, Eastleigh,...        3
# 19   40, Pantheon Road, Chandler's Ford, Eastleigh,...        3
# 20   5, Collett Close, Hedge End, Southampton, Hamp...        3
# 21   30, Crescent Road, North Baddesley, Southampto...        3
# 22   21, Queens Road, Chandler's Ford, Eastleigh, H...        4
# 23   7, Tyrrel Road, Chandler's Ford, Eastleigh, Ha...        4
# 24          176, Winchester Road, Southampton SO16 6UG        3
# 25   22, Mossleigh Avenue, Rownhams, Southampton, H...        3
# 26              7, Westover Road, Southampton SO16 9BJ        2
# 27       71, Bassett Green Close, Southampton SO16 3QX        4
# 28   11, Old Bridge House Road, Bursledon, Southamp...        3
# 29   23, Barton Drive, Hedge End, Southampton, Hamp...        3
# 30   Flat 10, Osborne House, Grosvenor Square, Sout...        2
# 33               1, Edwina Close, Southampton SO19 7BJ        4
# ..                                                 ...      ...
# 964  39, Wood End Way, Chandler's Ford, Eastleigh, ...        3
# 965  7, The Tanyards, Chandler's Ford, Eastleigh, H...        4
# 966  6, Partry Close, Chandler's Ford, Eastleigh, H...        4
# 967  10, Pembroke Close, Eastleigh, Hampshire SO50 4QY        3
# 968  5, Cox Row, Chandler's Ford, Eastleigh, Hampsh...        3
# 969  7, Cambridge Green, Chandler's Ford, Eastleigh...        3
# 970           4, Killarney Close, Southampton SO19 0PW        2
# 971  39, Belvedere Road, Dibden Purlieu, Southampto...        4
# 973  Flat 12a, Nightingale Walk, Royal Victoria Cou...        1
# 975           119, Firgrove Road, Southampton SO15 3ET        3
# 976            36, Blakeney Road, Southampton SO16 9PE        2
# 977  97, Paynes Road, Freemantle, Southampton SO15 3BX        3
# 979  50, Torridge Gardens, West End, Southampton, H...        2
# 981  31, Onibury Road, Midanbury, Southampton SO18 2DB        2
# 982    103, St Blaize Road, Romsey, Hampshire SO51 7JY        3
# 983  2, Coriander Drive, Totton, Southampton, Hamps...        2
# 985  2, Harewood Close, Boyatt Wood, Eastleigh, Ham...        2
# 986  41, Fallow Crescent, Hedge End, Southampton, H...        3
# 987  4, George Wright Close, Eastleigh, Hampshire S...        3
# 988  27, Lingwood Close, Bassett, Southampton SO16 7GB        4
# 989  3, Kirk Gardens, Totton, Southampton, Hampshir...        2
# 990               5, Burton Road, Southampton SO15 2HZ        4
# 991            21, Castle Street, Southampton SO14 6GZ        4
# 992  8, Court Close, Calmore, Southampton, Hampshir...        2
# 993     37, Sycamore Close, Romsey, Hampshire SO51 5SB        4
# 995  76, Pitmore Road, Allbrook, Eastleigh, Hampshi...        4
# 996  34, Devonshire Gardens, Bursledon, Southampton...        3
# 997       12, Tadburn Road, Romsey, Hampshire SO51 5AU        2
# 998  Treetops, Crampmoor Lane, Crampmoor, Romsey, H...        4
# 999  49, Summerfields, Locks Heath, Southampton, Ha...        4
#
#      Building Type Leasehold Type   Price
# 0         Terraced       Freehold  290000
# 1         Detached       Freehold  426500
# 2             Flat      Leasehold  240500
# 3         Terraced       Freehold  190000
# 4    Semi-Detached       Freehold  350000
# 5         Detached       Freehold  360000
# 6         Detached       Freehold  240000
# 7         Detached       Freehold  400000
# 8         Terraced       Freehold  257500
# 10   Semi-Detached       Freehold  256000
# 11   Semi-Detached       Freehold  250000
# 12        Detached       Freehold  274000
# 13        Terraced      Leasehold  205000
# 15   Semi-Detached       Freehold  239000
# 16        Terraced       Freehold  210000
# 17        Terraced       Freehold  217000
# 18        Terraced       Freehold  320000
# 19        Terraced       Freehold  295000
# 20   Semi-Detached       Freehold  290000
# 21        Detached       Freehold  278000
# 22        Detached       Freehold  586000
# 23        Detached       Freehold  620000
# 24        Terraced       Freehold  222000
# 25        Detached       Freehold  395000
# 26        Detached       Freehold  250000
# 27        Detached       Freehold  410000
# 28   Semi-Detached       Freehold  225000
# 29   Semi-Detached       Freehold  280000
# 30            Flat      Leasehold  233000
# 33   Semi-Detached       Freehold  280000
# ..             ...            ...     ...
# 964  Semi-Detached       Freehold  370000
# 965       Detached       Freehold  585000
# 966       Detached       Freehold  470000
# 967       Detached       Freehold  285000
# 968  Semi-Detached       Freehold  287500
# 969       Terraced       Freehold  215000
# 970           Flat      Leasehold  159995
# 971       Detached       Freehold  327500
# 973           Flat      Leasehold  129950
# 975       Terraced       Freehold  150000
# 976  Semi-Detached       Freehold  169500
# 977       Terraced       Freehold  205000
# 979       Terraced       Freehold  207000
# 981       Detached       Freehold  200000
# 982       Terraced       Freehold  235000
# 983  Semi-Detached       Freehold  223000
# 985  Semi-Detached       Freehold  199000
# 986       Detached       Freehold  284950
# 987       Terraced       Freehold  236000
# 988       Detached       Freehold  460000
# 989       Detached       Freehold  325000
# 990       Terraced       Freehold  219500
# 991       Terraced       Freehold  210000
# 992           Flat      Leasehold  175000
# 993       Terraced       Freehold  412500
# 995       Detached       Freehold  375000
# 996       Terraced       Freehold  244000
# 997  Semi-Detached       Freehold  335000
# 998       Detached       Freehold  735000
# 999       Detached       Freehold  380000
#
# [799 rows x 5 columns]

# %%
def post(x):
    y = x[-8:-4]
    return y

def post_full(x):
    y = x[-8:]
    return y
    

df["Postcode"] = df["Address"].apply(post)
df["Postcode Full"] = df["Address"].apply(post_full)
df_pc = df.sort_values(by=['Postcode'])
df_pc.to_csv("Southampton_Property_PastYear.csv")
df_pc
# Out:
#                                                Address Bedrooms  \
# 881         30, Gillcrest, Fareham, Hampshire PO14 4SH        3
# 45         51, Merryfield, Fareham, Hampshire PO14 4SF        4
# 849         3, Grassymead, Fareham, Hampshire PO14 4SQ        2
# 792  36, Sovereign Crescent, Fareham, Hampshire PO1...        4
# 550        16, Wheatlands, Fareham, Hampshire PO14 4SL        3
# 732  6, Rattigan Gardens, Whiteley, Fareham, Hampsh...        4
# 399  7, Maryat Way, Whiteley, Fareham, Hampshire PO...        3
# 778  14, Berber Close, Whiteley, Fareham, Hampshire...        3
# 963  91, Dumas Drive, Whiteley, Fareham, Hampshire ...        4
# 779  29, Angelica Way, Whiteley, Fareham, Hampshire...        3
# 780  3, Bronte Gardens, Whiteley, Fareham, Hampshir...        4
# 541  5, Christie Avenue, Whiteley, Fareham, Hampshi...        3
# 540  40, Andalusian Gardens, Whiteley, Fareham, Ham...        4
# 539  12, Connemara Crescent, Whiteley, Fareham, Ham...        4
# 733  24, Steinbeck Close, Whiteley, Fareham, Hampsh...        3
# 102  26, Saffron Way, Whiteley, Fareham, Hampshire ...        2
# 242  30, Lovage Road, Whiteley, Fareham, Hampshire ...        3
# 776  2, Persian Drive, Whiteley, Fareham, Hampshire...        4
# 777  65, Coriander Way, Whiteley, Fareham, Hampshir...        3
# 124         43, Liverpool Street, Southampton SO14 6FZ        2
# 126            70, Middle Street, Southampton SO14 6HW        2
# 237           32, Methuen Street, Southampton SO14 6FR        3
# 336           50, Rockstone Lane, Southampton SO14 6HZ        2
# 278            232, Northam Road, Southampton SO14 0QE        2
# 689           75, Methuen Street, Southampton SO14 6FR        2
# 337               85, Earls Road, Southampton SO14 6SG        2
# 842  Flat 30, Mauretania House, Kent Street, Southa...        4
# 319  Flat 94, Sapphire Court, Ocean Way, Southampto...        2
# 320  Flat 38, Sapphire Court, Ocean Way, Southampto...        2
# 461            27, Craven Street, Southampton SO14 1AX        2
# ..                                                 ...      ...
# 548  5, Hocombe Drive, Chandler's Ford, Eastleigh, ...        4
# 216  5, Colton Copse, Chandler's Ford, Eastleigh, H...        3
# 187  93, Hocombe Road, Chandler's Ford, Eastleigh, ...        4
# 71   116, Pine Road, Chandler's Ford, Eastleigh, Ha...        5
# 152  7, Burley Down, Chandler's Ford, Eastleigh, Ha...        4
# 63   21, Maytree Road, Chandler's Ford, Eastleigh, ...        3
# 186  19, Beechwood Crescent, Chandler's Ford, Eastl...        4
# 499  7, Northdene Road, Chandler's Ford, Eastleigh,...        3
# 552  34, Somerset Crescent, Chandler's Ford, Eastle...        3
# 553  56, Hut Farm Place, Chandler's Ford, Eastleigh...        4
# 185  74, Lakewood Road, Chandler's Ford, Eastleigh,...        4
# 244  7, Common Close, Chandler's Ford, Eastleigh, H...        4
# 184  Flat 8, Charlotte Court, Merdon Avenue, Chandl...        1
# 400  9, Donnington Drive, Chandler's Ford, Eastleig...        3
# 880  20, Pennard Way, Chandler's Ford, Eastleigh, H...        4
# 879  48, Monmouth Close, Chandler's Ford, Eastleigh...        2
# 557  106, Hut Farm Place, Chandler's Ford, Eastleig...        2
# 558  12, Alderwood Avenue, Chandler's Ford, Eastlei...        5
# 876  Willow Cottage, 244, Chestnut Avenue, Chandler...        2
# 875  5, Coach Hill Close, Chandler's Ford, Eastleig...        2
# 494  4, Goldwire Drive, Chandler's Ford, Eastleigh,...        4
# 947  6, Welles Road, Chandler's Ford, Eastleigh, Ha...        3
# 715  1a, Belmont Road, Chandler's Ford, Eastleigh, ...        2
# 595  15, Charnwood Crescent, Chandler's Ford, Eastl...        2
# 951  1, Welles Road, Chandler's Ford, Eastleigh, Ha...        3
# 712  22, Ashdown Road, Chandler's Ford, Eastleigh, ...        3
# 782  Flat 5a, Stewart House, Sycamore Avenue, Chand...        2
# 786  46, Chalvington Road, Chandler's Ford, Eastlei...        3
# 22   21, Queens Road, Chandler's Ford, Eastleigh, H...        4
# 306  12, Welles Road, Chandler's Ford, Eastleigh, H...        2
#
#      Building Type Leasehold Type   Price Postcode Postcode Full
# 881  Semi-Detached       Freehold  259000     PO14      PO14 4SH
# 45        Detached       Freehold  350000     PO14      PO14 4SF
# 849       Terraced       Freehold  214500     PO14      PO14 4SQ
# 792       Detached       Freehold  452500     PO14      PO14 4LT
# 550  Semi-Detached       Freehold  272500     PO14      PO14 4SL
# 732       Detached       Freehold  362500     PO15      PO15 7EA
# 399       Terraced       Freehold  306500     PO15      PO15 7NP
# 778  Semi-Detached       Freehold  302000     PO15      PO15 7HF
# 963       Detached       Freehold  390000     PO15      PO15 7FS
# 779       Terraced       Freehold  300000     PO15      PO15 7HY
# 780       Detached       Freehold  370000     PO15      PO15 7LF
# 541  Semi-Detached       Freehold  265000     PO15      PO15 7JE
# 540       Detached       Freehold  390000     PO15      PO15 7DU
# 539       Detached       Freehold  380000     PO15      PO15 7BN
# 733       Detached       Freehold  345000     PO15      PO15 7EX
# 102       Terraced       Freehold  225000     PO15      PO15 7LQ
# 242       Terraced       Freehold  294000     PO15      PO15 7LD
# 776       Detached       Freehold  699995     PO15      PO15 7BJ
# 777       Terraced       Freehold  300000     PO15      PO15 7HG
# 124       Terraced       Freehold  205000     SO14      SO14 6FZ
# 126       Terraced       Freehold  200000     SO14      SO14 6HW
# 237       Terraced       Freehold  280000     SO14      SO14 6FR
# 336       Terraced      Leasehold  206500     SO14      SO14 6HZ
# 278       Terraced       Freehold  178000     SO14      SO14 0QE
# 689  Semi-Detached       Freehold  202000     SO14      SO14 6FR
# 337       Terraced       Freehold  197500     SO14      SO14 6SG
# 842           Flat      Leasehold  118000     SO14      SO14 5SL
# 319           Flat      Leasehold  204000     SO14      SO14 3JX
# 320           Flat      Leasehold  230000     SO14      SO14 3JW
# 461           Flat      Leasehold  150000     SO14      SO14 1AX
# ..             ...            ...     ...      ...           ...
# 548       Detached       Freehold  550000     SO53      SO53 5QE
# 216  Semi-Detached       Freehold  300500     SO53      SO53 4HQ
# 187       Detached       Freehold  976600     SO53      SO53 5QB
# 71        Detached       Freehold  595000     SO53      SO53 1JT
# 152       Detached       Freehold  455000     SO53      SO53 4NR
# 63   Semi-Detached       Freehold  349950     SO53      SO53 5RT
# 186       Detached       Freehold  730000     SO53      SO53 5PE
# 499       Detached       Freehold  307500     SO53      SO53 3DW
# 552       Terraced       Freehold  233786     SO53      SO53 3FG
# 553       Terraced       Freehold  330000     SO53      SO53 3LQ
# 185       Detached       Freehold  980000     SO53      SO53 5AA
# 244       Detached       Freehold  360000     SO53      SO53 1HF
# 184           Flat      Leasehold  140000     SO53      SO53 1TZ
# 400       Detached       Freehold  330000     SO53      SO53 3PL
# 880       Detached       Freehold  440000     SO53      SO53 4NJ
# 879       Terraced       Freehold  225000     SO53      SO53 4SY
# 557           Flat      Leasehold  199950     SO53      SO53 3LR
# 558       Detached       Freehold  575000     SO53      SO53 4TH
# 876       Detached       Freehold  332000     SO53      SO53 3HN
# 875       Terraced       Freehold  225000     SO53      SO53 1UA
# 494       Detached       Freehold  612500     SO53      SO53 4LQ
# 947       Detached       Freehold  395000     SO53      SO53 2GQ
# 715       Detached       Freehold  260000     SO53      SO53 3EU
# 595       Terraced      Leasehold  180000     SO53      SO53 5QN
# 951       Detached       Freehold  305000     SO53      SO53 2GQ
# 712  Semi-Detached       Freehold  345000     SO53      SO53 5QW
# 782           Flat      Leasehold  175000     SO53      SO53 5RW
# 786       Detached       Freehold  395000     SO53      SO53 3DX
# 22        Detached       Freehold  586000     SO53      SO53 5AH
# 306  Semi-Detached       Freehold  272500     SO53      SO53 2GQ
#
# [799 rows x 7 columns]
